# %%
#1
import pandas as pd
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt

diabetes = load_diabetes()
print("Nazwy kolumn: ", diabetes.feature_names)
liczba_pacjentow = len(diabetes.target)
print("Liczba przebadanych pacjentów:", liczba_pacjentow)

plt.hist(diabetes.target)
plt.show()
# Out:
# Nazwy kolumn:  ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Liczba przebadanych pacjentów: 442

# %%
#2
from sklearn.datasets import load_iris
from collections import Counter

dataset_iris = load_iris()

print("Nazwy kolumn:", dataset_iris.feature_names)

nazwy_gatunkow = dataset_iris.target_names
print("Nazwy badanych gatunków kwiatków:", nazwy_gatunkow)

target_counts = Counter(dataset_iris.target)
for gatunek, count in zip(nazwy_gatunkow, target_counts.values()):
    print(f"Ilość przypadków dla gatunku {gatunek}: {count}")
# Out:
# Nazwy kolumn: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Nazwy badanych gatunków kwiatków: ['setosa' 'versicolor' 'virginica']
# Ilość przypadków dla gatunku setosa: 50
# Ilość przypadków dla gatunku versicolor: 50
# Ilość przypadków dla gatunku virginica: 50

# %%
#3
from sklearn.datasets import make_classification
X_bin, y_bin = make_classification(n_samples=500, n_features=5, n_classes=2)
print (X_bin)
# Out:
# [[-1.83572551 -1.33289483 -0.59820948  0.44510966 -2.78292492]
#  [-1.59863384  1.11544689 -0.7945769   2.04743993 -1.09989498]
#  [-1.71933555  0.0839661  -0.84723113  1.38845015 -1.83171891]
#  ...
#  [-0.39724931  2.86706628 -0.80710923  2.39733986  1.23269927]
#  [-0.90628002  1.42043078 -1.06817905  1.73538204 -0.16527642]
#  [-2.03551892 -1.97323263  0.46298466  0.13239841 -3.37380719]]

# %%
#4
X_multi, y_multi = make_classification(n_samples=1000, n_features=5, n_classes=5, n_informative=3, n_clusters_per_class=1)
print(X_multi)
# Out:
# [[-0.23825101 -2.92075825  3.29697809 -3.64035017 -1.00162262]
#  [-0.48906338 -1.00119175 -0.61423753 -0.46682684 -1.44930871]
#  [-0.81574976 -1.99668277  2.07210261 -2.83262009  1.51306225]
#  ...
#  [ 0.42485626  0.8729779  -0.86562379  1.26136803 -0.85869483]
#  [-0.16024893 -0.35599399  0.29500845 -0.46991373  0.21281346]
#  [ 0.52292195  1.29896849 -1.68791358  2.04487437 -1.47114822]]

# %%
#5
from sklearn.datasets import make_regression

X_reg1, y_reg1 = make_regression(n_samples=400, n_features=4)
print(X_reg1)
# Out:
# [[-1.02414081 -0.15871914  0.26902486 -1.09457218]
#  [ 0.26005287 -0.54270083 -1.77295298  0.39131474]
#  [ 0.8379433  -1.94317977  0.58075579 -0.61560937]
#  ...
#  [-1.61965498 -1.10264035  0.25650307 -0.28843071]
#  [-0.82893618  2.14911415 -0.11022324 -0.01695479]
#  [-1.57106581 -0.15162472 -0.406999    0.3491235 ]]

# %%
#6
from sklearn.datasets import make_regression

X_reg2, y_reg2 = make_regression(n_samples=600, n_features=6)
print(X_reg2)
# Out:
# [[ 0.33931366  1.29600866  0.95634349 -0.0652378   0.94069837  1.11430283]
#  [ 1.08145604 -0.5659376  -0.06657712 -0.83312614 -0.07776975 -0.92089794]
#  [-1.13458951  1.10803181 -1.80249584  0.81197915  0.19640625 -0.28111042]
#  ...
#  [-0.93399753  0.69651222  0.69491583 -0.8706807  -1.14569215 -0.02711231]
#  [-0.71802896  0.72631719  0.14618271  3.12981473 -0.01020031  0.1270568 ]
#  [-0.24737784  0.44089118  0.52920176  1.1485249  -0.8475984  -1.15914705]]

# %%
#7
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, train_size=250)

X_train
y_train
X_test
y_test
# Out:
# array([ 69., 288., 281.,  65.,  55.,  69.,  54.,  60., 173., 308., 183.,
#        129., 249., 310., 142., 131., 128.,  95., 131.,  70., 135., 202.,
#         55., 168., 129.,  72., 122.,  85., 166., 126.,  68.,  71., 302.,
#        281., 163.,  87., 263.,  90., 115., 158., 150.,  52.,  91., 170.,
#        346.,  97., 150.,  59., 154., 296., 273., 272.,  63., 261., 237.,
#         53., 270., 208.,  39.,  96.,  87., 292.,  88., 173., 295., 187.,
#        317., 181., 184., 128., 137., 283., 125., 200.,  92.,  63., 225.,
#        217.,  49., 118., 142., 200.,  51., 171., 258.,  72.,  48., 262.,
#        124., 219., 321.,  71., 116., 163., 277.,  75.,  84., 102., 332.,
#         47., 160.,  84., 198.,  64., 196., 124.,  75., 189., 178.,  83.,
#         43.,  59.,  90., 148.,  96., 257., 252.,  40.,  81., 103., 185.,
#         90., 103.,  63., 246.,  97.,  61., 200., 174., 310.,  72., 156.,
#        107.,  74., 113., 259.,  60., 178., 118.,  77., 303.,  50., 237.,
# ...

# %%
#8
from sklearn.datasets import load_iris
import numpy as np
from sklearn.model_selection import train_test_split
iris = load_iris()
X_train, X_valid, Y_train,Y_valid = train_test_split(
    iris.data,iris.target, train_size=0.7, random_state=42)
X_train
X_valid
Y_train
Y_valid
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0])

# %%
#9
from sklearn.datasets import make_classification
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

X_bin, y_bin = make_classification(n_samples=500, n_features=5, n_classes=2)
print (X_bin)

X_train, X_valid, Y_train,Y_valid = train_test_split(
    X_bin, y_bin, train_size=0.5, random_state=42, stratify=y_bin)

plt.hist(X_bin) 
plt.show()  
plt.hist(y_bin)  
plt.show()
# Out:
# [[ 0.05768034  0.28713668 -0.06356035  0.12286178  0.41195043]
#  [ 0.67312148 -0.5870698   0.58960514 -0.11896828  0.6877752 ]
#  [ 1.19010451 -1.65969568  1.25264264  0.12743577  0.56558928]
#  ...
#  [ 0.09958998  0.98832084 -0.27626726  0.17728582  1.22655117]
#  [-0.00808578  0.42657653 -0.14891701  0.19489718  0.43062148]
#  [ 0.68319342 -0.00478352  0.39859597 -0.4920567   1.31641183]]

# %%
#10
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

X_reg1, y_reg1 = make_regression(n_samples=600, n_features=6)
print(X_reg1)

X_train, X_valid, Y_train, Y_valid = train_test_split(
    X_reg1, y_reg1, test_size=100, random_state=42)

plt.hist(X_reg1)
plt.show()
plt.hist(y_reg1)
plt.show()
# Out:
# [[ 0.13444312 -0.73315631  2.23308383 -0.11796231  1.62071819  0.12643401]
#  [ 1.33400985  1.35699862 -0.97377326  0.89645473  0.09465119  0.57169062]
#  [ 1.22512408 -0.12388043 -0.121186    0.09832044 -0.63749565  0.65497015]
#  ...
#  [ 1.79016863 -1.63938244  0.14051698 -0.30078939  1.78125774 -0.19904562]
#  [ 1.75600984  0.10325285 -1.05822199  0.62937512 -0.63250571 -0.05273776]
#  [ 0.90353857  0.38546315 -0.25370205  1.35610555  0.04894961  0.29961187]]
